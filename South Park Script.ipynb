# %%
# %%html
# <style>
#   td {text-align: left !important;}
# </style>
# Out:
# <style>
#   td {text-align: left !important;}
# </style>

# %% [markdown]
# # Processing South Park Wikia
# This Python notebook processes the raw script data available on the South Park Wikia. Does it by looping through season by season, episode by episode.
#
# The scripts for each episode are parsed by going through the main table in on the webpage for each episode. The main table contains two columns, the right column for the character speaking the line and the left column for the line spoken.
#
# | Character       | Line                                                                  |
# |:----------------|:----------------------------------------------------------------------|
# | Kyle Broflovski | Ah, damn it! My little brother's trying to follow me to school again. |
# | Ike Broflovski  | Zeeponaner.                                                           |
# | Kyle            | Ike, you can't come to school with me. *[Ike Chortles.]*              |
# |                 | *At the bus stop*                                                     |
#
# The following is done for processing:
# 1. The asides (e.g. '[Ike Chortles]') are removed.
# 2. Characters with shortened names (e.g. Kyle and Kyle Broflovski) have their lines under the same name.
# 3. Rows where actions are written (e.g. 'At the bus stop') are removed (rows with no character cell).

# %%
# necessary imports
import pandas as pd
import requests
import bs4
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### URL and Script Processing
# Processes the season URLs to navigate to the correct link for each season as well as removes the on-screen actions shown in the captions (e.g. '[Ike Chortles]' or '[Cartman bunny hops]').

# %%
# main page link
url = "http://southpark.wikia.com"
# location of all links to scripts
portal = "/wiki/Portal:Scripts"

def strip_season_url(link):
    return link[link.find('/Season'):]

def strip_extras(text):
    text = re.sub(r'\[[^\]]*\]', ' ', text).strip()
    return text

# %% [markdown]
# ### File Output
# Writes the given character and line data to a given CSV file. Allows to write csv files per episode or per season, or even the entire script data in one file.

# %%
def write_data(dictionary, file_name):
    df = pd.DataFrame(dictionary)
    df = df[['season', 'episode', 'character', 'line']]
    df.to_csv(file_name + '.csv', encoding='utf-8')

# %% [markdown]
# ### Character Processing
# Processes the cast list on the Wikia page per episode and returns a list containing all the characters that appear in the episode. The characters for each line is also processed because after their first occurance, the character names are shortend (e.g. Kyle Broflovski to Kyle and Mr. Herbert Garrison to Mr. Garrison).

# %%
# creates a list of the characters from the episode
def get_characters(ul_list):
    characters = list()
    for li in ul_list.findAll('li'):
        characters.append(li.get_text().strip())
    return characters

# %%
# matches a shorter character name to the full name from the episode cast
def match_character(name, char_list):
    subset = name.split(' ')
    for char in char_list:
        if set(subset).issubset(set(char.split(' '))):
            return char
    return name

# %% [markdown]
# ### Episode Processing
# Processes the main table on the page, which contains two columns: 'character' and 'line'. Each row contains one line said by a character. The lines containing actions on-screen (e.g. 'At the bus stop') are removed by checking for empty character cells, but non-empty line cells. Lines that multiple characters say at the same time are split apart into two, adjacent lines.

# %%
# parse the episode by getting all characters and matching lines for each character
def parse_episode(link, season, episode):
    print('----------Episode:', link)
    episode_page = BeautifulSoup(requests.get(link).content, 'html.parser')
    script_table = episode_page.findAll('table')[1]
    chars = get_characters(episode_page.find(id='mw-content-text').find('ul'))
    
    print('-------# of Lines:', len(script_table.find_all('tr')))
    script_table = script_table.find_all('tr')[1 : -1]
    
    temp = []
    
    for row in script_table:
        cell = row.contents
        if len(cell) >= 3:
            c = str(cell[1].text)
            l = str(cell[2].text)
            if not len(c) == 1 :
                name = re.sub('[^a-zA-Z1-9 ,]', ' ', c)
                name = re.sub('\\s+', ' ', name).strip()
                stripped_line = l.strip()
                for n in name.split(', '):
                    n = match_character(n, chars)
                    d = {}
                    d['season'] = season
                    d['episode'] = episode
                    d['character'] = n
                    d['line'] = stripped_line
                    temp.append(d)
    write_data(temp, 'data/season ' + str(season) + '/episode ' + str(episode))
    return temp

# %% [markdown]
# ### Season Processing
# Processes the main table on the page that contains a link to each of the South Park episodes of a season--a loop goes through the link to each episode and returns a list containing the character and the text they said over all the seasons.

# %%
# loops through all episodes of a single season
def parse_season(link, season):
    print('\n-----------Season:', link)
    
    season_page = BeautifulSoup(requests.get(link).content, 'html.parser')
    season_table = season_page.find('div', id='gallery-0')
    
    count = 1
    
    print('----------# of Ep:', len(season_table.find_all('a', class_='link-internal')))
    temp = []
    for a in season_table.find_all('a', class_='link-internal'):
        k = parse_episode(url + a['href'], season, count)        
        count += 1
        temp.extend(k)
        if season == 21 and count == 10:
            break
    write_data(temp, 'data/seasons/season ' + str(season))
    return temp

# %%
main_page = BeautifulSoup(requests.get(url + portal).content, 'html.parser')
main_table = main_page.find('div', id='gallery-0')

count = 1

a = main_table.findAll('a', class_='link-internal')[0]
temp = []

for a in main_table.findAll('a', class_='link-internal'):
    season_url = strip_season_url(a['href'])
    k = parse_season(url + portal + season_url, count)
    temp.extend(k)

    count += 1
    
df = pd.DataFrame(temp)
df = df[['season', 'episode', 'character', 'line']]
df.to_csv('data/all-seasons.csv', encoding='utf-8')
df.to_csv('data/all-seasons-sep.csv', encoding='utf-8', sep='}')
df['line'] = df['line'].apply(strip_extras)
df.to_csv('data/all-seasons-cleaned-sep.csv', sep='}', encoding='utf-8')
# Out:
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_One
# ----------# of Ep: 13
# ----------Episode: http://southpark.wikia.com/wiki/Cartman_Gets_an_Anal_Probe/Script
# -------# of Lines: 507
# ----------Episode: http://southpark.wikia.com/wiki/Weight_Gain_4000/Script
# -------# of Lines: 399
# ----------Episode: http://southpark.wikia.com/wiki/Volcano/Script
# -------# of Lines: 406
# ----------Episode: http://southpark.wikia.com/wiki/Big_Gay_Al%27s_Big_Gay_Boat_Ride/Script
# -------# of Lines: 528
# ----------Episode: http://southpark.wikia.com/wiki/An_Elephant_Makes_Love_to_a_Pig/Script
# -------# of Lines: 139
# ----------Episode: http://southpark.wikia.com/wiki/Death/Script
# -------# of Lines: 528
# ----------Episode: http://southpark.wikia.com/wiki/Pinkeye/Script
# -------# of Lines: 523
# ----------Episode: http://southpark.wikia.com/wiki/Starvin%27_Marvin/Script
# -------# of Lines: 472
# ----------Episode: http://southpark.wikia.com/wiki/Mr._Hankey,_the_Christmas_Poo/Script
# -------# of Lines: 479
# ----------Episode: http://southpark.wikia.com/wiki/Damien/Script
# -------# of Lines: 475
# ----------Episode: http://southpark.wikia.com/wiki/Tom%27s_Rhinoplasty/Script
# -------# of Lines: 107
# ----------Episode: http://southpark.wikia.com/wiki/Mecha-Streisand/Script
# -------# of Lines: 33
# ----------Episode: http://southpark.wikia.com/wiki/Cartman%27s_Mom_is_a_Dirty_Slut/Script
# -------# of Lines: 447
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Two
# ----------# of Ep: 18
# ----------Episode: http://southpark.wikia.com/wiki/Terrance_and_Phillip_in_Not_Without_My_Anus/Script
# -------# of Lines: 492
# ----------Episode: http://southpark.wikia.com/wiki/Cartman%27s_Mom_is_Still_a_Dirty_Slut/Script
# -------# of Lines: 448
# ----------Episode: http://southpark.wikia.com/wiki/Chickenlover/Script
# -------# of Lines: 420
# ----------Episode: http://southpark.wikia.com/wiki/Ike%27s_Wee_Wee/Script
# -------# of Lines: 547
# ----------Episode: http://southpark.wikia.com/wiki/Conjoined_Fetus_Lady/Script
# -------# of Lines: 496
# ----------Episode: http://southpark.wikia.com/wiki/The_Mexican_Staring_Frog_of_Southern_Sri_Lanka/Script
# -------# of Lines: 10
# ----------Episode: http://southpark.wikia.com/wiki/City_on_the_Edge_of_Forever_(Flashbacks)/Script
# -------# of Lines: 109
# ----------Episode: http://southpark.wikia.com/wiki/Summer_Sucks/Script
# -------# of Lines: 497
# ----------Episode: http://southpark.wikia.com/wiki/Chef%27s_Chocolate_Salty_Balls/Script
# -------# of Lines: 499
# ----------Episode: http://southpark.wikia.com/wiki/Chickenpox/Script
# -------# of Lines: 515
# ----------Episode: http://southpark.wikia.com/wiki/Roger_Ebert_Should_Lay_off_the_Fatty_Foods/Script
# -------# of Lines: 510
# ----------Episode: http://southpark.wikia.com/wiki/Clubhouses/Script
# -------# of Lines: 612
# ----------Episode: http://southpark.wikia.com/wiki/Cow_Days/Script
# -------# of Lines: 336
# ----------Episode: http://southpark.wikia.com/wiki/Chef_Aid/Script
# -------# of Lines: 523
# ----------Episode: http://southpark.wikia.com/wiki/Spookyfish/Script
# -------# of Lines: 402
# ----------Episode: http://southpark.wikia.com/wiki/Merry_Christmas_Charlie_Manson!/Script
# -------# of Lines: 41
# ----------Episode: http://southpark.wikia.com/wiki/Gnomes/Script
# -------# of Lines: 148
# ----------Episode: http://southpark.wikia.com/wiki/Prehistoric_Ice_Man/Script
# -------# of Lines: 487
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Three
# ----------# of Ep: 17
# ----------Episode: http://southpark.wikia.com/wiki/Rainforest_Shmainforest/Script
# -------# of Lines: 359
# ----------Episode: http://southpark.wikia.com/wiki/Spontaneous_Combustion/Script
# -------# of Lines: 159
# ----------Episode: http://southpark.wikia.com/wiki/The_Succubus/Script
# -------# of Lines: 186
# ----------Episode: http://southpark.wikia.com/wiki/Jakovasaurs/Script
# -------# of Lines: 275
# ----------Episode: http://southpark.wikia.com/wiki/Tweek_vs._Craig/Script
# -------# of Lines: 387
# ----------Episode: http://southpark.wikia.com/wiki/Sexual_Harassment_Panda/Script
# -------# of Lines: 340
# ----------Episode: http://southpark.wikia.com/wiki/Cat_Orgy/Script
# -------# of Lines: 314
# ----------Episode: http://southpark.wikia.com/wiki/Two_Guys_Naked_in_a_Hot_Tub/Script
# -------# of Lines: 395
# ----------Episode: http://southpark.wikia.com/wiki/Jewbilee/Script
# -------# of Lines: 322
# ----------Episode: http://southpark.wikia.com/wiki/Korn%27s_Groovy_Pirate_Ghost_Mystery/Script
# -------# of Lines: 404
# ----------Episode: http://southpark.wikia.com/wiki/Chinpokomon/Script
# -------# of Lines: 430
# ----------Episode: http://southpark.wikia.com/wiki/Hooked_on_Monkey_Fonics/Script
# -------# of Lines: 365
# ----------Episode: http://southpark.wikia.com/wiki/Starvin%27_Marvin_in_Space/Script
# -------# of Lines: 344
# ----------Episode: http://southpark.wikia.com/wiki/The_Red_Badge_of_Gayness/Script
# -------# of Lines: 373
# ----------Episode: http://southpark.wikia.com/wiki/Mr._Hankey%27s_Christmas_Classics/Script
# -------# of Lines: 364
# ----------Episode: http://southpark.wikia.com/wiki/Are_You_There_God%3F_It%27s_Me,_Jesus/Script
# -------# of Lines: 309
# ----------Episode: http://southpark.wikia.com/wiki/World_Wide_Recorder_Concert/Script
# -------# of Lines: 361
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Four
# ----------# of Ep: 17
# ----------Episode: http://southpark.wikia.com/wiki/The_Tooth_Fairy_Tats_2000/Script
# -------# of Lines: 400
# ----------Episode: http://southpark.wikia.com/wiki/Cartman%27s_Silly_Hate_Crime_2000/Script
# -------# of Lines: 387
# ----------Episode: http://southpark.wikia.com/wiki/Timmy_2000/Script
# -------# of Lines: 367
# ----------Episode: http://southpark.wikia.com/wiki/Quintuplets_2000/Script
# -------# of Lines: 395
# ----------Episode: http://southpark.wikia.com/wiki/Cartman_Joins_NAMBLA/Script
# -------# of Lines: 369
# ----------Episode: http://southpark.wikia.com/wiki/Cherokee_Hair_Tampons/Script
# -------# of Lines: 354
# ----------Episode: http://southpark.wikia.com/wiki/Chef_Goes_Nanners/Script
# -------# of Lines: 346
# ----------Episode: http://southpark.wikia.com/wiki/Something_You_Can_Do_with_Your_Finger/Script
# -------# of Lines: 385
# ----------Episode: http://southpark.wikia.com/wiki/Do_the_Handicapped_Go_to_Hell%3F/Script
# -------# of Lines: 379
# ----------Episode: http://southpark.wikia.com/wiki/Probably/Script
# -------# of Lines: 405
# ----------Episode: http://southpark.wikia.com/wiki/Fourth_Grade/Script
# -------# of Lines: 367
# ----------Episode: http://southpark.wikia.com/wiki/Trapper_Keeper/Script
# -------# of Lines: 344
# ----------Episode: http://southpark.wikia.com/wiki/Helen_Keller!_The_Musical/Script
# -------# of Lines: 304
# ----------Episode: http://southpark.wikia.com/wiki/Pip/Script
# -------# of Lines: 290
# ----------Episode: http://southpark.wikia.com/wiki/Fat_Camp/Script
# -------# of Lines: 374
# ----------Episode: http://southpark.wikia.com/wiki/The_Wacky_Molestation_Adventure/Script
# -------# of Lines: 354
# ----------Episode: http://southpark.wikia.com/wiki/A_Very_Crappy_Christmas/Script
# -------# of Lines: 374
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Five
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/It_Hits_the_Fan/Script
# -------# of Lines: 138
# ----------Episode: http://southpark.wikia.com/wiki/Cripple_Fight/Script
# -------# of Lines: 316
# ----------Episode: http://southpark.wikia.com/wiki/Super_Best_Friends/Script
# -------# of Lines: 364
# ----------Episode: http://southpark.wikia.com/wiki/Scott_Tenorman_Must_Die/Script
# -------# of Lines: 353
# ----------Episode: http://southpark.wikia.com/wiki/Terrance_and_Phillip:_Behind_the_Blow/Script
# -------# of Lines: 351
# ----------Episode: http://southpark.wikia.com/wiki/Cartmanland/Script
# -------# of Lines: 311
# ----------Episode: http://southpark.wikia.com/wiki/Proper_Condom_Use/Script
# -------# of Lines: 344
# ----------Episode: http://southpark.wikia.com/wiki/Towelie/Script
# -------# of Lines: 387
# ----------Episode: http://southpark.wikia.com/wiki/Osama_bin_Laden_Has_Farty_Pants/Script
# -------# of Lines: 344
# ----------Episode: http://southpark.wikia.com/wiki/How_to_Eat_with_Your_Butt/Script
# -------# of Lines: 303
# ----------Episode: http://southpark.wikia.com/wiki/The_Entity/Script
# -------# of Lines: 355
# ----------Episode: http://southpark.wikia.com/wiki/Here_Comes_the_Neighborhood/Script
# -------# of Lines: 376
# ----------Episode: http://southpark.wikia.com/wiki/Kenny_Dies/Script
# -------# of Lines: 274
# ----------Episode: http://southpark.wikia.com/wiki/Butters%27_Very_Own_Episode/Script
# -------# of Lines: 324
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Six
# ----------# of Ep: 17
# ----------Episode: http://southpark.wikia.com/wiki/Jared_Has_Aides/Script
# -------# of Lines: 387
# ----------Episode: http://southpark.wikia.com/wiki/Asspen/Script
# -------# of Lines: 317
# ----------Episode: http://southpark.wikia.com/wiki/Freak_Strike/Script
# -------# of Lines: 365
# ----------Episode: http://southpark.wikia.com/wiki/Fun_with_Veal/Script
# -------# of Lines: 422
# ----------Episode: http://southpark.wikia.com/wiki/The_New_Terrance_and_Phillip_Movie_Trailer/Script
# -------# of Lines: 345
# ----------Episode: http://southpark.wikia.com/wiki/Professor_Chaos/Script
# -------# of Lines: 243
# ----------Episode: http://southpark.wikia.com/wiki/The_Simpsons_Already_Did_It/Script
# -------# of Lines: 316
# ----------Episode: http://southpark.wikia.com/wiki/Red_Hot_Catholic_Love/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/Free_Hat/Script
# -------# of Lines: 322
# ----------Episode: http://southpark.wikia.com/wiki/Bebe%27s_Boobs_Destroy_Society/Script
# -------# of Lines: 393
# ----------Episode: http://southpark.wikia.com/wiki/Child_Abduction_is_Not_Funny/Script
# -------# of Lines: 275
# ----------Episode: http://southpark.wikia.com/wiki/A_Ladder_to_Heaven/Script
# -------# of Lines: 304
# ----------Episode: http://southpark.wikia.com/wiki/The_Return_of_the_Fellowship_of_the_Ring_to_the_Two_Towers/Script
# -------# of Lines: 374
# ----------Episode: http://southpark.wikia.com/wiki/The_Death_Camp_of_Tolerance/Script
# -------# of Lines: 303
# ----------Episode: http://southpark.wikia.com/wiki/The_Biggest_Douche_in_the_Universe/Script
# -------# of Lines: 358
# ----------Episode: http://southpark.wikia.com/wiki/My_Future_Self_n%27_Me/Script
# -------# of Lines: 333
# ----------Episode: http://southpark.wikia.com/wiki/Red_Sleigh_Down/Script
# -------# of Lines: 300
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Seven
# ----------# of Ep: 15
# ----------Episode: http://southpark.wikia.com/wiki/Cancelled/Script
# -------# of Lines: 358
# ----------Episode: http://southpark.wikia.com/wiki/Krazy_Kripples/Script
# -------# of Lines: 287
# ----------Episode: http://southpark.wikia.com/wiki/Toilet_Paper/Script
# -------# of Lines: 342
# ----------Episode: http://southpark.wikia.com/wiki/I%27m_a_Little_Bit_Country/Script
# -------# of Lines: 268
# ----------Episode: http://southpark.wikia.com/wiki/Fat_Butt_and_Pancake_Head/Script
# -------# of Lines: 394
# ----------Episode: http://southpark.wikia.com/wiki/Lil%27_Crime_Stoppers/Script
# -------# of Lines: 353
# ----------Episode: http://southpark.wikia.com/wiki/Red_Man%27s_Greed/Script
# -------# of Lines: 289
# ----------Episode: http://southpark.wikia.com/wiki/South_Park_is_Gay!/Script
# -------# of Lines: 361
# ----------Episode: http://southpark.wikia.com/wiki/Christian_Rock_Hard/Script
# -------# of Lines: 168
# ----------Episode: http://southpark.wikia.com/wiki/Grey_Dawn/Script
# -------# of Lines: 246
# ----------Episode: http://southpark.wikia.com/wiki/Casa_Bonita/Script
# -------# of Lines: 272
# ----------Episode: http://southpark.wikia.com/wiki/All_About_Mormons/Script
# -------# of Lines: 100
# ----------Episode: http://southpark.wikia.com/wiki/Butt_Out/Script
# -------# of Lines: 5
# ----------Episode: http://southpark.wikia.com/wiki/Raisins/Script
# -------# of Lines: 312
# ----------Episode: http://southpark.wikia.com/wiki/It%27s_Christmas_in_Canada/Script
# -------# of Lines: 322
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Eight
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/Good_Times_with_Weapons/Script
# -------# of Lines: 314
# ----------Episode: http://southpark.wikia.com/wiki/Up_the_Down_Steroid/Script
# -------# of Lines: 244
# ----------Episode: http://southpark.wikia.com/wiki/The_Passion_of_the_Jew/Script
# -------# of Lines: 295
# ----------Episode: http://southpark.wikia.com/wiki/You_Got_F%27d_in_the_A/Script
# -------# of Lines: 349
# ----------Episode: http://southpark.wikia.com/wiki/AWESOM-O/Script
# -------# of Lines: 89
# ----------Episode: http://southpark.wikia.com/wiki/The_Jeffersons/Script
# -------# of Lines: 401
# ----------Episode: http://southpark.wikia.com/wiki/Goobacks/Script
# -------# of Lines: 223
# ----------Episode: http://southpark.wikia.com/wiki/Douche_and_Turd/Script
# -------# of Lines: 141
# ----------Episode: http://southpark.wikia.com/wiki/Something_Wall-Mart_This_Way_Comes/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/Pre-School/Script
# -------# of Lines: 5
# ----------Episode: http://southpark.wikia.com/wiki/Quest_for_Ratings/Script
# -------# of Lines: 65
# ----------Episode: http://southpark.wikia.com/wiki/Stupid_Spoiled_Whore_Video_Playset/Script
# -------# of Lines: 299
# ----------Episode: http://southpark.wikia.com/wiki/Cartman%27s_Incredible_Gift/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/Woodland_Critter_Christmas/Script
# -------# of Lines: 319
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Nine
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/Mr._Garrison%27s_Fancy_New_Vagina/Script
# -------# of Lines: 262
# ----------Episode: http://southpark.wikia.com/wiki/Die_Hippie,_Die/Script
# -------# of Lines: 287
# ----------Episode: http://southpark.wikia.com/wiki/Wing/Script
# -------# of Lines: 295
# ----------Episode: http://southpark.wikia.com/wiki/Best_Friends_Forever/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/The_Losing_Edge/Script
# -------# of Lines: 314
# ----------Episode: http://southpark.wikia.com/wiki/The_Death_of_Eric_Cartman/Script
# -------# of Lines: 295
# ----------Episode: http://southpark.wikia.com/wiki/Erection_Day/Script
# -------# of Lines: 255
# ----------Episode: http://southpark.wikia.com/wiki/Two_Days_Before_the_Day_After_Tomorrow/Script
# -------# of Lines: 289
# ----------Episode: http://southpark.wikia.com/wiki/Marjorine/Script
# -------# of Lines: 283
# ----------Episode: http://southpark.wikia.com/wiki/Follow_That_Egg!/Script
# -------# of Lines: 247
# ----------Episode: http://southpark.wikia.com/wiki/Ginger_Kids/Script
# -------# of Lines: 260
# ----------Episode: http://southpark.wikia.com/wiki/Trapped_in_the_Closet/Script
# -------# of Lines: 277
# ----------Episode: http://southpark.wikia.com/wiki/Free_Willzyx/Script
# -------# of Lines: 293
# ----------Episode: http://southpark.wikia.com/wiki/Bloody_Mary/Script
# -------# of Lines: 265
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Ten
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/The_Return_of_Chef/Script
# -------# of Lines: 299
# ----------Episode: http://southpark.wikia.com/wiki/Smug_Alert!/Script
# -------# of Lines: 301
# ----------Episode: http://southpark.wikia.com/wiki/Cartoon_Wars_Part_I/Script
# -------# of Lines: 229
# ----------Episode: http://southpark.wikia.com/wiki/Cartoon_Wars_Part_II/Script
# -------# of Lines: 262
# ----------Episode: http://southpark.wikia.com/wiki/A_Million_Little_Fibers/Script
# -------# of Lines: 268
# ----------Episode: http://southpark.wikia.com/wiki/ManBearPig/Script
# -------# of Lines: 260
# ----------Episode: http://southpark.wikia.com/wiki/Tsst/Script
# -------# of Lines: 313
# ----------Episode: http://southpark.wikia.com/wiki/Make_Love,_Not_Warcraft/Script
# -------# of Lines: 322
# ----------Episode: http://southpark.wikia.com/wiki/Mystery_of_the_Urinal_Deuce/Script
# -------# of Lines: 250
# ----------Episode: http://southpark.wikia.com/wiki/Miss_Teacher_Bangs_a_Boy/Script
# -------# of Lines: 323
# ----------Episode: http://southpark.wikia.com/wiki/Hell_on_Earth_2006/Script
# -------# of Lines: 279
# ----------Episode: http://southpark.wikia.com/wiki/Go_God_Go/Script
# -------# of Lines: 265
# ----------Episode: http://southpark.wikia.com/wiki/Go_God_Go_XII/Script
# -------# of Lines: 286
# ----------Episode: http://southpark.wikia.com/wiki/Stanley%27s_Cup/Script
# -------# of Lines: 258
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Eleven
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/With_Apologies_to_Jesse_Jackson/Script
# -------# of Lines: 249
# ----------Episode: http://southpark.wikia.com/wiki/Cartman_Sucks/Script
# -------# of Lines: 290
# ----------Episode: http://southpark.wikia.com/wiki/Lice_Capades/Script
# -------# of Lines: 260
# ----------Episode: http://southpark.wikia.com/wiki/The_Snuke/Script
# -------# of Lines: 366
# ----------Episode: http://southpark.wikia.com/wiki/Fantastic_Easter_Special/Script
# -------# of Lines: 264
# ----------Episode: http://southpark.wikia.com/wiki/D-Yikes!/Script
# -------# of Lines: 286
# ----------Episode: http://southpark.wikia.com/wiki/Night_of_the_Living_Homeless/Script
# -------# of Lines: 298
# ----------Episode: http://southpark.wikia.com/wiki/Le_Petit_Tourette/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/More_Crap/Script
# -------# of Lines: 247
# ----------Episode: http://southpark.wikia.com/wiki/Imaginationland/Script
# -------# of Lines: 38
# ----------Episode: http://southpark.wikia.com/wiki/Imaginationland,_Episode_II/Script
# -------# of Lines: 283
# ----------Episode: http://southpark.wikia.com/wiki/Imaginationland,_Episode_III/Script
# -------# of Lines: 286
# ----------Episode: http://southpark.wikia.com/wiki/Guitar_Queer-O/Script
# -------# of Lines: 259
# ----------Episode: http://southpark.wikia.com/wiki/The_List/Script
# -------# of Lines: 227
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Twelve
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/Tonsil_Trouble/Script
# -------# of Lines: 274
# ----------Episode: http://southpark.wikia.com/wiki/Britney%27s_New_Look/Script
# -------# of Lines: 249
# ----------Episode: http://southpark.wikia.com/wiki/Major_Boobage/Script
# -------# of Lines: 197
# ----------Episode: http://southpark.wikia.com/wiki/Canada_on_Strike/Script
# -------# of Lines: 240
# ----------Episode: http://southpark.wikia.com/wiki/Eek,_A_Penis!/Script
# -------# of Lines: 231
# ----------Episode: http://southpark.wikia.com/wiki/Over_Logging/Script
# -------# of Lines: 262
# ----------Episode: http://southpark.wikia.com/wiki/Super_Fun_Time/Script
# -------# of Lines: 325
# ----------Episode: http://southpark.wikia.com/wiki/The_China_Probrem/Script
# -------# of Lines: 278
# ----------Episode: http://southpark.wikia.com/wiki/Breast_Cancer_Show_Ever/Script
# -------# of Lines: 250
# ----------Episode: http://southpark.wikia.com/wiki/Pandemic/Script
# -------# of Lines: 275
# ----------Episode: http://southpark.wikia.com/wiki/Pandemic_2:_The_Startling/Script
# -------# of Lines: 253
# ----------Episode: http://southpark.wikia.com/wiki/About_Last_Night.../Script
# -------# of Lines: 274
# ----------Episode: http://southpark.wikia.com/wiki/Elementary_School_Musical/Script
# -------# of Lines: 301
# ----------Episode: http://southpark.wikia.com/wiki/The_Ungroundable/Script
# -------# of Lines: 255
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Thirteen
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/The_Ring/Script
# -------# of Lines: 302
# ----------Episode: http://southpark.wikia.com/wiki/The_Coon/Script
# -------# of Lines: 237
# ----------Episode: http://southpark.wikia.com/wiki/Margaritaville/Script
# -------# of Lines: 217
# ----------Episode: http://southpark.wikia.com/wiki/Eat,_Pray,_Queef/Script
# -------# of Lines: 271
# ----------Episode: http://southpark.wikia.com/wiki/Fishsticks/Script
# -------# of Lines: 268
# ----------Episode: http://southpark.wikia.com/wiki/Pinewood_Derby/Script
# -------# of Lines: 249
# ----------Episode: http://southpark.wikia.com/wiki/Fatbeard/Script
# -------# of Lines: 239
# ----------Episode: http://southpark.wikia.com/wiki/Dead_Celebrities/Script
# -------# of Lines: 260
# ----------Episode: http://southpark.wikia.com/wiki/Butters%27_Bottom_Bitch/Script
# -------# of Lines: 272
# ----------Episode: http://southpark.wikia.com/wiki/W.T.F./Script
# -------# of Lines: 330
# ----------Episode: http://southpark.wikia.com/wiki/Whale_Whores/Script
# -------# of Lines: 230
# ----------Episode: http://southpark.wikia.com/wiki/The_F_Word/Script
# -------# of Lines: 234
# ----------Episode: http://southpark.wikia.com/wiki/Dances_with_Smurfs/Script
# -------# of Lines: 232
# ----------Episode: http://southpark.wikia.com/wiki/Pee/Script
# -------# of Lines: 284
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Fourteen
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/Sexual_Healing/Script
# -------# of Lines: 240
# ----------Episode: http://southpark.wikia.com/wiki/The_Tale_of_Scrotie_McBoogerballs/Script
# -------# of Lines: 259
# ----------Episode: http://southpark.wikia.com/wiki/Medicinal_Fried_Chicken/Script
# -------# of Lines: 271
# ----------Episode: http://southpark.wikia.com/wiki/You_Have_0_Friends/Script
# -------# of Lines: 280
# ----------Episode: http://southpark.wikia.com/wiki/200/Script
# -------# of Lines: 305
# ----------Episode: http://southpark.wikia.com/wiki/201/Script
# -------# of Lines: 269
# ----------Episode: http://southpark.wikia.com/wiki/Crippled_Summer/Script
# -------# of Lines: 278
# ----------Episode: http://southpark.wikia.com/wiki/Poor_and_Stupid/Script
# -------# of Lines: 263
# ----------Episode: http://southpark.wikia.com/wiki/It%27s_a_Jersey_Thing/Script
# -------# of Lines: 276
# ----------Episode: http://southpark.wikia.com/wiki/Insheeption/Script
# -------# of Lines: 351
# ----------Episode: http://southpark.wikia.com/wiki/Coon_2:_Hindsight/Script
# -------# of Lines: 285
# ----------Episode: http://southpark.wikia.com/wiki/Mysterion_Rises/Script
# -------# of Lines: 215
# ----------Episode: http://southpark.wikia.com/wiki/Coon_vs._Coon_%26_Friends/Script
# -------# of Lines: 214
# ----------Episode: http://southpark.wikia.com/wiki/Cr%C3%A8me_Fraiche/Script
# -------# of Lines: 257
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Fifteen
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/HUMANCENTiPAD/Script
# -------# of Lines: 285
# ----------Episode: http://southpark.wikia.com/wiki/Funnybot/Script
# -------# of Lines: 216
# ----------Episode: http://southpark.wikia.com/wiki/Royal_Pudding/Script
# -------# of Lines: 170
# ----------Episode: http://southpark.wikia.com/wiki/T.M.I./Script
# -------# of Lines: 246
# ----------Episode: http://southpark.wikia.com/wiki/Crack_Baby_Athletic_Association/Script
# -------# of Lines: 236
# ----------Episode: http://southpark.wikia.com/wiki/City_Sushi/Script
# -------# of Lines: 235
# ----------Episode: http://southpark.wikia.com/wiki/You%27re_Getting_Old/Script
# -------# of Lines: 271
# ----------Episode: http://southpark.wikia.com/wiki/Ass_Burgers/Script
# -------# of Lines: 255
# ----------Episode: http://southpark.wikia.com/wiki/The_Last_of_the_Meheecans/Script
# -------# of Lines: 223
# ----------Episode: http://southpark.wikia.com/wiki/Bass_to_Mouth/Script
# -------# of Lines: 287
# ----------Episode: http://southpark.wikia.com/wiki/Broadway_Bro_Down/Script
# -------# of Lines: 312
# ----------Episode: http://southpark.wikia.com/wiki/1%25/Script
# -------# of Lines: 239
# ----------Episode: http://southpark.wikia.com/wiki/A_History_Channel_Thanksgiving/Script
# -------# of Lines: 255
# ----------Episode: http://southpark.wikia.com/wiki/The_Poor_Kid/Script
# -------# of Lines: 256
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Sixteen
# ----------# of Ep: 14
# ----------Episode: http://southpark.wikia.com/wiki/Reverse_Cowgirl/Script
# -------# of Lines: 257
# ----------Episode: http://southpark.wikia.com/wiki/Cash_For_Gold/Script
# -------# of Lines: 206
# ----------Episode: http://southpark.wikia.com/wiki/Faith_Hilling/Script
# -------# of Lines: 274
# ----------Episode: http://southpark.wikia.com/wiki/Jewpacabra/Script
# -------# of Lines: 224
# ----------Episode: http://southpark.wikia.com/wiki/Butterballs/Script
# -------# of Lines: 232
# ----------Episode: http://southpark.wikia.com/wiki/I_Should_Have_Never_Gone_Ziplining/Script
# -------# of Lines: 269
# ----------Episode: http://southpark.wikia.com/wiki/Cartman_Finds_Love/Script
# -------# of Lines: 288
# ----------Episode: http://southpark.wikia.com/wiki/Sarcastaball/Script
# -------# of Lines: 240
# ----------Episode: http://southpark.wikia.com/wiki/Raising_the_Bar/Script
# -------# of Lines: 204
# ----------Episode: http://southpark.wikia.com/wiki/Insecurity/Script
# -------# of Lines: 272
# ----------Episode: http://southpark.wikia.com/wiki/Going_Native/Script
# -------# of Lines: 222
# ----------Episode: http://southpark.wikia.com/wiki/A_Nightmare_on_Face_Time/Script
# -------# of Lines: 285
# ----------Episode: http://southpark.wikia.com/wiki/A_Scause_For_Applause/Script
# -------# of Lines: 248
# ----------Episode: http://southpark.wikia.com/wiki/Obama_Wins!/Script
# -------# of Lines: 274
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Seventeen
# ----------# of Ep: 10
# ----------Episode: http://southpark.wikia.com/wiki/Let_Go,_Let_Gov/Script
# -------# of Lines: 243
# ----------Episode: http://southpark.wikia.com/wiki/Informative_Murder_Porn/Script
# -------# of Lines: 258
# ----------Episode: http://southpark.wikia.com/wiki/World_War_Zimmerman/Script
# -------# of Lines: 290
# ----------Episode: http://southpark.wikia.com/wiki/Goth_Kids_3:_Dawn_of_the_Posers/Script
# -------# of Lines: 288
# ----------Episode: http://southpark.wikia.com/wiki/Taming_Strange/Script
# -------# of Lines: 261
# ----------Episode: http://southpark.wikia.com/wiki/Ginger_Cow/Script
# -------# of Lines: 258
# ----------Episode: http://southpark.wikia.com/wiki/Black_Friday/Script
# -------# of Lines: 231
# ----------Episode: http://southpark.wikia.com/wiki/A_Song_of_Ass_and_Fire/Script
# -------# of Lines: 241
# ----------Episode: http://southpark.wikia.com/wiki/Titties_and_Dragons/Script
# -------# of Lines: 259
# ----------Episode: http://southpark.wikia.com/wiki/The_Hobbit/Script
# -------# of Lines: 235
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Eighteen
# ----------# of Ep: 10
# ----------Episode: http://southpark.wikia.com/wiki/Go_Fund_Yourself/Script
# -------# of Lines: 258
# ----------Episode: http://southpark.wikia.com/wiki/Gluten_Free_Ebola/Script
# -------# of Lines: 313
# ----------Episode: http://southpark.wikia.com/wiki/The_Cissy/Script
# -------# of Lines: 231
# ----------Episode: http://southpark.wikia.com/wiki/Handicar/Script
# -------# of Lines: 258
# ----------Episode: http://southpark.wikia.com/wiki/The_Magic_Bush/Script
# -------# of Lines: 267
# ----------Episode: http://southpark.wikia.com/wiki/Freemium_Isn%27t_Free/Script
# -------# of Lines: 268
# ----------Episode: http://southpark.wikia.com/wiki/Grounded_Vindaloop/Script
# -------# of Lines: 326
# ----------Episode: http://southpark.wikia.com/wiki/Cock_Magic/Script
# -------# of Lines: 276
# ----------Episode: http://southpark.wikia.com/wiki/REHASH/Script
# -------# of Lines: 281
# ----------Episode: http://southpark.wikia.com/wiki/HappyHolograms/Script
# -------# of Lines: 319
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Nineteen
# ----------# of Ep: 10
# ----------Episode: http://southpark.wikia.com/wiki/Stunning_and_Brave/Script
# -------# of Lines: 259
# ----------Episode: http://southpark.wikia.com/wiki/Where_My_Country_Gone%3F/Script
# -------# of Lines: 238
# ----------Episode: http://southpark.wikia.com/wiki/The_City_Part_of_Town/Script
# -------# of Lines: 164
# ----------Episode: http://southpark.wikia.com/wiki/You%27re_Not_Yelping/Script
# -------# of Lines: 298
# ----------Episode: http://southpark.wikia.com/wiki/Safe_Space/Script
# -------# of Lines: 247
# ----------Episode: http://southpark.wikia.com/wiki/Tweek_x_Craig/Script
# -------# of Lines: 265
# ----------Episode: http://southpark.wikia.com/wiki/Naughty_Ninjas/Script
# -------# of Lines: 250
# ----------Episode: http://southpark.wikia.com/wiki/Sponsored_Content/Script
# -------# of Lines: 238
# ----------Episode: http://southpark.wikia.com/wiki/Truth_and_Advertising/Script
# -------# of Lines: 301
# ----------Episode: http://southpark.wikia.com/wiki/PC_Principal_Final_Justice/Script
# -------# of Lines: 56
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Twenty
# ----------# of Ep: 10
# ----------Episode: http://southpark.wikia.com/wiki/Member_Berries/Script
# -------# of Lines: 232
# ----------Episode: http://southpark.wikia.com/wiki/Skank_Hunt/Script
# -------# of Lines: 229
# ----------Episode: http://southpark.wikia.com/wiki/The_Damned/Script
# -------# of Lines: 201
# ----------Episode: http://southpark.wikia.com/wiki/Wieners_Out/Script
# -------# of Lines: 268
# ----------Episode: http://southpark.wikia.com/wiki/Douche_and_a_Danish/Script
# -------# of Lines: 153
# ----------Episode: http://southpark.wikia.com/wiki/Fort_Collins/Script
# -------# of Lines: 102
# ----------Episode: http://southpark.wikia.com/wiki/Oh,_Jeez/Script
# -------# of Lines: 21
# ----------Episode: http://southpark.wikia.com/wiki/Members_Only/Script
# -------# of Lines: 289
# ----------Episode: http://southpark.wikia.com/wiki/Not_Funny/Script
# -------# of Lines: 270
# ----------Episode: http://southpark.wikia.com/wiki/The_End_of_Serialization_as_We_Know_It/Script
# -------# of Lines: 394
#
# -----------Season: http://southpark.wikia.com/wiki/Portal:Scripts/Season_Twenty-One
# ----------# of Ep: 10
# ----------Episode: http://southpark.wikia.com/wiki/White_People_Renovating_Houses/Script
# -------# of Lines: 263
# ----------Episode: http://southpark.wikia.com/wiki/Put_It_Down/Script
# -------# of Lines: 127
# ----------Episode: http://southpark.wikia.com/wiki/Holiday_Special/Script
# -------# of Lines: 236
# ----------Episode: http://southpark.wikia.com/wiki/Franchise_Prequel/Script
# -------# of Lines: 271
# ----------Episode: http://southpark.wikia.com/wiki/Hummels_%26_Heroin/Script
# -------# of Lines: 252
# ----------Episode: http://southpark.wikia.com/wiki/Sons_A_Witches/Script
# -------# of Lines: 324
# ----------Episode: http://southpark.wikia.com/wiki/Doubling_Down/Script
# -------# of Lines: 258
# ----------Episode: http://southpark.wikia.com/wiki/Moss_Piglets/Script
# -------# of Lines: 264
# ----------Episode: http://southpark.wikia.com/wiki/SUPER_HARD_PCness/Script
# -------# of Lines: 244
